# %% [markdown]
# # Shark Attack

# %%
import pandas as pd

import xlrd

file_location = '"C:\Users\estef\Downloads\GSAF5.xls"'
workbook = read_excel(file_location)
# Out:
#   Cell In[2], line 5
#     file_location = '"C:\Users\estef\Downloads\GSAF5.xls"'
#                                                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 3-4: truncated \UXXXXXXXX escape
